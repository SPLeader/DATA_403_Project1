# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Functions

# %%
def drop_vars(df):
    columns_to_drop = [
        # Those we want to remove for all analyses
        'Date','Vodka Sold PC','Gin Sold PC', 'Rum Sold PC', 'Whiskey Sold PC', 'Tequila Sold PC', 'Other Alc Sold PC',
        'Gin Sold PROP','Rum Sold PROP','Whiskey Sold PROP','Tequila Sold PROP','Other Alc Sold PROP','Vodka Sold PROP',
        # Remove linearly dependent columns
        'is_weekend', 'Young Prop', 'LowIncome Prop', 'Other Prop',
        # remove target columns
        'Volume Sold PC', 'Bottles Sold PC', 'Sales Volume PC']
    df = df.drop(columns_to_drop, axis = 1)
    return df


# specify what columns to make dummies for 
def make_dummies(df, columns):
    new_cols = []
    for col in columns:
        if col == 'Year':
            # get dummies for year 
            year_dummies = pd.get_dummies(df['Year'], drop_first = True)
            year_dummies.columns = ["year_" + str(column) for column in year_dummies.columns]
            new_cols.append(year_dummies)
            df = df.drop(['Year'], axis = 1)
        elif col == 'Month':
            # get dummies for month
            month_dummies = pd.get_dummies(df['Month'], drop_first = True)
            month_dummies.columns = ["month_" + str(column) for column in month_dummies.columns]
            new_cols.append(month_dummies)
            df = df.drop(['Month'], axis = 1)
        elif col == 'County':
            # get dummies for county
            county_dummies = pd.get_dummies(df['County'], drop_first = True)
            new_cols.append(county_dummies)
            df = df.drop(['County'], axis = 1)
        elif col == 'DOW':
            dow_dummies = pd.get_dummies(df['DOW'], drop_first = True)
            new_cols.append(dow_dummies)
            df = df.drop(['DOW'], axis = 1)
            
    full_set = [df]+new_cols
    df = pd.concat(full_set, axis = 1)
    return df


def get_intermediate_matrix(df, response_df, numeric_columns, standardize=True):
    
    
    # if there are numeric columns:
    if numeric_columns is not None and standardize is True:
        #non_numeric_columns = [column for column in df.columns if column not in numeric_columns]
        # standard scale non categorical columns
        ct = make_column_transformer(
                (StandardScaler(), numeric_columns)
                , remainder='passthrough')
        ct_array = ct.fit_transform(df)
        column_order = ['Intercept'] + numeric_columns 
        x_mat = np.asmatrix(ct_array) 
    # only categorical columns
    else:
        non_numeric_columns = [column for column in df.columns]
        column_order = ['Intercept'] + non_numeric_columns
        x_mat = np.asmatrix(df)   
        
    intercept_array = np.ones((x_mat.shape[0], 1))
    x_mat = np.concatenate((intercept_array, x_mat),1)
    response_mat = np.asmatrix(response_df).getT()
    
    matrix_without_target = x_mat
    matrix_with_target = np.concatenate((response_mat, x_mat), 1)
    return matrix_with_target, matrix_without_target, response_mat, column_order


def get_betas(x_mat, response_mat, reg_type, lambda_val=100):
    if reg_type == 'OLS':
        # ols beta estimates
        betas = np.matmul(np.matmul(np.linalg.inv(np.matmul(x_mat.transpose(), x_mat)), x_mat.transpose()), response_mat)
    elif reg_type == 'Ridge':
        lambda_mat = np.diag(np.full(x_mat.shape[1], lambda_val))
        betas = np.matmul(np.matmul((np.matmul(x_mat.getT(), x_mat)+lambda_mat).getI(), x_mat.getT()), response_mat)
    return betas


def show_beta_summary(betas, column_order):
    return pd.DataFrame({'Variable' : column_order, 'Coefficient' : betas.A1}).sort_values(by = 'Coefficient', ascending = False)

# %%
def run_cross_val(data, k, penalty="OLS", lam=100):
    # shuffle matrix
    np.random.shuffle(data)
    k_splits = np.array_split(data, k)
    r2_list = []
    rmse_list = []
    metrics = {}
    for i in range(k):
        # Get train/validation split
        validate = k_splits[i]
        train = np.concatenate([k_splits[j] for j in range(k) if j != i])
        
        y_train = train[:, 0]
        x_train = train[:, 1:]
        
        y_val = validate[:,0]
        x_val = validate[:, 1:]
        # Train the model on the training data
        if penalty == "OLS":
            # ols beta estimates
            betas = np.matmul(np.matmul(np.matmul(x_train.getT(), x_train).getI(), x_train.getT()), y_train)
        elif penalty == "Ridge":
            # make diagonal matrix for lambda
            lambda_mat = np.diag(np.full(x_train.shape[1], lam))
            # ols beta estimates
            betas = np.matmul(np.matmul((np.matmul(x_train.getT(), x_train)+lambda_mat).getI(), x_train.getT()), y_train)
        else:
            raise ValueError("not a recognizable penalty")
        
        # Make predictions on validation data
        y_pred = np.matmul(x_val, betas)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred))
        rmse_list.append(rmse)
        r2 = r2_score(y_val, y_pred)
        r2_list.append(r2)
        
    metrics['avg r_2'] = np.mean(r2_list)
    metrics['avg rmse'] = np.mean(rmse_list)
    
    return metrics

# %%
# prepare the df to plot RMSE/lambda
def roc_df(matrix, lambda_list, k):
    df = {'Lambda': [], 'Avg. RMSE': []}
    for l in lambda_list:
        # print('Working on lambda {}'.format(l))
        metrics = run_cross_val(matrix, k, "Ridge")
        df['Lambda'].append(l)
        df['Avg. RMSE'].append(metrics['avg rmse'])
    return pd.DataFrame(df)

# %% [markdown]
# ## Reading in Dataset

# %%
# reading in raw data
raw_df = pd.read_csv("Data/Aggregated Data/harlech_data_proportions.csv", low_memory = False)

# %% [markdown]
# ## Train Dev Test Split

# %%
# pulling out response variables
response_df = raw_df[['Volume Sold PC', 'Bottles Sold PC', 'Sales Volume PC']]
# dropping the variables we are currently not using
df = drop_vars(raw_df)
# 0.1 test split 
X_train, X_test, y_train, y_test = train_test_split(df, response_df, test_size=0.1, random_state=420)

# %% [markdown]
# # *** DO NOT TOUCH X_TEST AND Y_TEST UNTIL THE VERY END ***
# - I set a random state already, so results should be consistent

# %%
# X_train X_test, y_train, y_test are all regular dfs
X_train.head()
# Out:
#            County  Year  Poverty   Population      DOW  Month  White Prop  \
# 18073     O'BRIEN  2014       7.3     14045.0  Tuesday      2    0.947985
# 50415        IOWA  2018       8.4     16150.0   Monday     12    0.959950
# 59342  BLACK HAWK  2019      15.5    131089.0  Tuesday     12    0.830555
# 30060       BOONE  2015      10.1     26468.0  Tuesday      9    0.971857
# 17082        LINN  2013       9.8    216567.0   Monday     12    0.897466
#
#        Black Prop  Native American Prop  Asian Prop  Pacific Prop  Two+ Prop  \
# 18073    0.005109              0.002058    0.008445      0.000142   0.012347
# 50415    0.005509              0.000248    0.003776      0.000000   0.027050
# 59342    0.096151              0.003968    0.026993      0.002784   0.028836
# 30060    0.008901              0.002045    0.003220      0.000379   0.012462
# 17082    0.042222              0.002433    0.019862      0.000152   0.028476
#
#        HighIncome Prop  MidIncome Prop  Middle-Old Prop  Middle-Young Prop  \
# 18073         0.128670        0.659689         0.295180           0.218584
# 50415         0.205333        0.630667         0.283241           0.231381
# 59342         0.209806        0.543299         0.226826           0.241214
# 30060         0.145129        0.643683         0.293791           0.245383
# 17082         0.211278        0.585274         0.280189           0.277637
#
#        Old Prop
# 18073  0.364049
# 50415  0.352249
# 59342  0.319122
# 30060  0.324965
# 17082  0.275762

# %%
y_train.head()
# Out:
#        Volume Sold PC  Bottles Sold PC  Sales Volume PC
# 18073        0.178702         0.146315         1.822865
# 50415        0.061034         0.061300         0.760484
# 59342        0.156045         0.240005         2.845622
# 30060        0.009056         0.008425         0.139549
# 17082        0.016383         0.018766         0.260010

# %% [markdown]
# # Predictive Model

# %%
# numeric columns for the current full predictive model
numeric_columns = ['Poverty ', 'Population', 'White Prop', 'Black Prop',
                    'Native American Prop', 'Asian Prop', 'Pacific Prop', 'Two+ Prop',
                    'HighIncome Prop', 'MidIncome Prop', 'Middle-Old Prop','Middle-Young Prop', 'Old Prop']

# %% [markdown]
# ## Sales Volume PC

# %%
X_train.columns
# Out:
# Index([u'County', u'Year', u'Poverty ', u'Population', u'DOW', u'Month',
#        u'White Prop', u'Black Prop', u'Native American Prop', u'Asian Prop',
#        u'Pacific Prop', u'Two+ Prop', u'HighIncome Prop', u'MidIncome Prop',
#        u'Middle-Old Prop', u'Middle-Young Prop', u'Old Prop'],
#       dtype='object')

# %%
# drop county because it's confounding
X_train_no_county = X_train.drop(columns=['County'])
# making dummies, indicate in argument what columns to dummify
df_sv = make_dummies(X_train_no_county, ['DOW', 'Month', 'Year'])

# get all the matrices needed for cross val
# passes in the df with dummies, the response var, and all the numeric columns of interest for standard scaling
sv_mat_with, sv_mat_without, sv_response_mat, sv_col_order = get_intermediate_matrix(df_sv, 
                                                                                     y_train['Sales Volume PC'], 
                                                                                     numeric_columns, 
                                                                                     True)

# %% [markdown]
# ### OLS

# %%
# run cross val
# 5 folds
# OLS, returns avg r2 and rmse
run_cross_val(sv_mat_with, 5, "OLS")
# Out:
# {'avg r_2': 0.11002834497095784, 'avg rmse': 0.7264078462026251}

# %% [markdown]
# ### Ridge

# %%
# same thing but with ridge
run_cross_val(sv_mat_with, 5, "Ridge", 100)
# Out:
# {'avg r_2': 0.10902333617628628, 'avg rmse': 0.726855701926598}

# %%
range_test = np.arange(1,5000,50)
roc = roc_df(sv_mat_with, range_test, 2)
roc.plot.line(x='Lambda', y='Avg. RMSE')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-aa09b717595b> in <module>()
#       1 range_test = np.arange(1,5000,50)
#       2 roc = roc_df(sv_mat_with, range_test, 2)
# ----> 3 roc.plot.line(x='Lambda', y='Avg. RMSE')
#
# C:\Users\bella\Anaconda3\envs\stats\lib\site-packages\pandas\plotting\_core.pyc in line(self, x, y, **kwds)
#    3004             >>> lines = df.plot.line(x='pig', y='horse')
#    3005         """
# -> 3006         return self(kind='line', x=x, y=y, **kwds)
#    3007
#    3008     def bar(self, x=None, y=None, **kwds):
#
# C:\Users\bella\Anaconda3\envs\stats\lib\site-packages\pandas\plotting\_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# C:\Users\bella\Anaconda3\envs\stats\lib\site-packages\pandas\plotting\_core.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1971                  yerr=yerr, xerr=xerr,
#    1972                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1973                  **kwds)
#    1974
#    1975
#
# C:\Users\bella\Anaconda3\envs\stats\lib\site-packages\pandas\plotting\_core.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1797                     data.columns = label_name
#    1798
# -> 1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
#    1801     plot_obj.generate()
#
# C:\Users\bella\Anaconda3\envs\stats\lib\site-packages\pandas\plotting\_core.pyc in __init__(self, data, **kwargs)
#     948
#     949     def __init__(self, data, **kwargs):
# --> 950         MPLPlot.__init__(self, data, **kwargs)
#     951         if self.stacked:
#     952             self.data = self.data.fillna(value=0)
#
# C:\Users\bella\Anaconda3\envs\stats\lib\site-packages\pandas\plotting\_core.pyc in __init__(self, data, kind, by, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, fig, title, xlim, ylim, xticks, yticks, sort_columns, fontsize, secondary_y, colormap, table, layout, **kwds)
#      96                  table=False, layout=None, **kwds):
#      97
# ---> 98         _raise_if_no_mpl()
#      99         _converter._WARN = False
#     100         self.data = data
#
# C:\Users\bella\Anaconda3\envs\stats\lib\site-packages\pandas\plotting\_core.pyc in _raise_if_no_mpl()
#      46     # TODO(mpl_converter): remove once converter is explicit
#      47     if not _HAS_MPL:
# ---> 48         raise ImportError("matplotlib is required for plotting.")
#      49
#      50
#
# ImportError: matplotlib is required for plotting.

# %% [markdown]
# ## Example where I don't standardize numeric columns

# %%
sv_mat_with, sv_mat_without, sv_response_mat, sv_col_order = get_intermediate_matrix(df_sv, 
                                                                                     y_train['Sales Volume PC'], 
                                                                                     numeric_columns, 
                                                                                     False) # make this flag False to not standard for OLS
run_cross_val(sv_mat_with, 5, "OLS")

# %% [markdown]
# # Subset of Variables Example

# %% [markdown]
# ## Bottles Sold PC

# %%
# choosing variables of interest
subset_example = X_train[['County', 'Month', 'Year', 'DOW']]
# make dummies
subset_bs = make_dummies(subset_example, ['County','DOW', 'Month', 'Year'])

# get matrices
# THERE ARE NO NUMERIC COLUMNS SO I PASS IN NONE FOR THAT ARGUMENT
bs_mat_with, bs_mat_without, bs_response_mat, bs_col_order = get_intermediate_matrix(subset_bs, y_train['Bottles Sold PC'], None)

# %%
run_cross_val(bs_mat_with, 5, "OLS")

# %% [markdown]
# ## Best Subsets

# %%
from itertools import combinations

features = {}
columns = X_train.columns
best_r2_subsets = []
best_rmse_subsets = []


for i in range(1, 7):
    best_r2_val = 0
    best_r2_subset= []
    best_rmse_val = 99
    best_rmse_subset= []
    for k in [list(j) for j in combinations(columns, i)]:
        ##find best subset based on r2
        if set(best_r2_subsets).issubset(k) :
            print(k)
            subset_example = X_train[k]
            # make dummies
            subset_bs = make_dummies(subset_example, k)

            # get matrices
            # THERE ARE NO NUMERIC COLUMNS SO I PASS IN NONE FOR THAT ARGUMENT
            bs_mat_with, bs_mat_without, bs_response_mat, bs_col_order = get_intermediate_matrix(subset_bs, y_train['Bottles Sold PC'], subset_bs.columns)
            r2 = run_cross_val(bs_mat_with, 5, "OLS")['avg r_2']
            if r2 > best_r2_val:
                best_r2_val=r2
                best_r2_subset=k
        ##find best subset based on rmse
        if set(best_rmse_subsets).issubset(k) :
            print(k)
            subset_example = X_train[k]
            # make dummies
            subset_bs = make_dummies(subset_example, k)

            # get matrices
            # THERE ARE NO NUMERIC COLUMNS SO I PASS IN NONE FOR THAT ARGUMENT
            bs_mat_with, bs_mat_without, bs_response_mat, bs_col_order = get_intermediate_matrix(subset_bs, y_train['Bottles Sold PC'], subset_bs.columns)
            rmse = run_cross_val(bs_mat_with, 5, "OLS")['avg rmse']
            if rmse < best_rmse_val:
                best_rmse_val=rmse
                best_rmse_subset=k
    print("Best Subset of size ", i, ": ", best_r2_subset, " has r2:", best_r2_val)
    print("Best Subset of size ", i, ": ", best_rmse_subset, " has rmse:", best_rmse_val)
    best_r2_subsets = best_r2_subset
    best_rmse_subsets = best_rmse_subset
# Out:
# ['County']
# ['County']
# ['Year']
# ['Year']
# ['Poverty ']
# ['Poverty ']
# ['Population']
# ['Population']
# ['DOW']
# ['DOW']
# ['Month']
# ['Month']
# ['White Prop']
# ['White Prop']
# ['Black Prop']
# ['Black Prop']
# ['Native American Prop']
# ['Native American Prop']
# ['Asian Prop']
# ['Asian Prop']
# ['Pacific Prop']
# ['Pacific Prop']
# ['Two+ Prop']
# ['Two+ Prop']
# ['HighIncome Prop']
# ['HighIncome Prop']
# ['MidIncome Prop']
# ['MidIncome Prop']
# ['Middle-Old Prop']
# ['Middle-Old Prop']
# ['Middle-Young Prop']
# ['Middle-Young Prop']
# ['Old Prop']
# ['Old Prop']
# Best Subset of size  1 :  ['County']  has r2: 0.24784667416713368
# Best Subset of size  1 :  ['County']  has rmse: 0.048295648924419315
# ['County', 'Year']
# ['County', 'Year']
# ['County', 'Poverty ']
# ['County', 'Poverty ']
# ['County', 'Population']
# ['County', 'Population']
# ['County', 'DOW']
# ['County', 'DOW']
# ['County', 'Month']
# ['County', 'Month']
# ['County', 'White Prop']
# ['County', 'White Prop']
# ['County', 'Black Prop']
# ['County', 'Black Prop']
# ['County', 'Native American Prop']
# ['County', 'Native American Prop']
# ['County', 'Asian Prop']
# ['County', 'Asian Prop']
# ['County', 'Pacific Prop']
# ['County', 'Pacific Prop']
# ['County', 'Two+ Prop']
# ['County', 'Two+ Prop']
# ['County', 'HighIncome Prop']
# ['County', 'HighIncome Prop']
# ['County', 'MidIncome Prop']
# ['County', 'MidIncome Prop']
# ['County', 'Middle-Old Prop']
# ['County', 'Middle-Old Prop']
# ['County', 'Middle-Young Prop']
# ['County', 'Middle-Young Prop']
# ['County', 'Old Prop']
# ['County', 'Old Prop']
# Best Subset of size  2 :  ['County', 'Year']  has r2: 0.31592051626558415
# Best Subset of size  2 :  ['County', 'Year']  has rmse: 0.04606567581594454
# ['County', 'Year', 'Poverty ']
# ['County', 'Year', 'Poverty ']
# ['County', 'Year', 'Population']
# ['County', 'Year', 'Population']
# ['County', 'Year', 'DOW']
# ['County', 'Year', 'DOW']
# ['County', 'Year', 'Month']
# ['County', 'Year', 'Month']
# ['County', 'Year', 'White Prop']
# ['County', 'Year', 'White Prop']
# ['County', 'Year', 'Black Prop']
# ['County', 'Year', 'Black Prop']
# ['County', 'Year', 'Native American Prop']
# ['County', 'Year', 'Native American Prop']
# ['County', 'Year', 'Asian Prop']
# ['County', 'Year', 'Asian Prop']
# ['County', 'Year', 'Pacific Prop']
# ['County', 'Year', 'Pacific Prop']
# ['County', 'Year', 'Two+ Prop']
# ['County', 'Year', 'Two+ Prop']
# ['County', 'Year', 'HighIncome Prop']
# ['County', 'Year', 'HighIncome Prop']
# ['County', 'Year', 'MidIncome Prop']
# ['County', 'Year', 'MidIncome Prop']
# ['County', 'Year', 'Middle-Old Prop']
# ['County', 'Year', 'Middle-Old Prop']
# ['County', 'Year', 'Middle-Young Prop']
# ['County', 'Year', 'Middle-Young Prop']
# ['County', 'Year', 'Old Prop']
# ['County', 'Year', 'Old Prop']
# Best Subset of size  3 :  ['County', 'Year', 'Month']  has r2: 0.32003961325264835
# Best Subset of size  3 :  ['County', 'Year', 'Month']  has rmse: 0.045914048612127834
# ['County', 'Year', 'Poverty ', 'Month']
# ['County', 'Year', 'Poverty ', 'Month']
# ['County', 'Year', 'Population', 'Month']
# ['County', 'Year', 'Population', 'Month']
# ['County', 'Year', 'DOW', 'Month']
# ['County', 'Year', 'DOW', 'Month']
# ['County', 'Year', 'Month', 'White Prop']
# ['County', 'Year', 'Month', 'White Prop']
# ['County', 'Year', 'Month', 'Black Prop']
# ['County', 'Year', 'Month', 'Black Prop']
# ['County', 'Year', 'Month', 'Native American Prop']
# ['County', 'Year', 'Month', 'Native American Prop']
# ['County', 'Year', 'Month', 'Asian Prop']
# ['County', 'Year', 'Month', 'Asian Prop']
# ['County', 'Year', 'Month', 'Pacific Prop']
# ['County', 'Year', 'Month', 'Pacific Prop']
# ['County', 'Year', 'Month', 'Two+ Prop']
# ['County', 'Year', 'Month', 'Two+ Prop']
# ['County', 'Year', 'Month', 'HighIncome Prop']
# ['County', 'Year', 'Month', 'HighIncome Prop']
# ['County', 'Year', 'Month', 'MidIncome Prop']
# ['County', 'Year', 'Month', 'MidIncome Prop']
# ['County', 'Year', 'Month', 'Middle-Old Prop']
# ['County', 'Year', 'Month', 'Middle-Old Prop']
# ['County', 'Year', 'Month', 'Middle-Young Prop']
# ['County', 'Year', 'Month', 'Middle-Young Prop']
# ['County', 'Year', 'Month', 'Old Prop']
# ['County', 'Year', 'Month', 'Old Prop']
# Best Subset of size  4 :  ['County', 'Year', 'DOW', 'Month']  has r2: 0.3214400818151578
# Best Subset of size  4 :  ['County', 'Year', 'DOW', 'Month']  has rmse: 0.04588640590599163
# ['County', 'Year', 'Poverty ', 'DOW', 'Month']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month']
# ['County', 'Year', 'Population', 'DOW', 'Month']
# ['County', 'Year', 'Population', 'DOW', 'Month']
# ['County', 'Year', 'DOW', 'Month', 'White Prop']
# ['County', 'Year', 'DOW', 'Month', 'White Prop']
# ['County', 'Year', 'DOW', 'Month', 'Black Prop']
# ['County', 'Year', 'DOW', 'Month', 'Black Prop']
# ['County', 'Year', 'DOW', 'Month', 'Native American Prop']
# ['County', 'Year', 'DOW', 'Month', 'Native American Prop']
# ['County', 'Year', 'DOW', 'Month', 'Asian Prop']
# ['County', 'Year', 'DOW', 'Month', 'Asian Prop']
# ['County', 'Year', 'DOW', 'Month', 'Pacific Prop']
# ['County', 'Year', 'DOW', 'Month', 'Pacific Prop']
# ['County', 'Year', 'DOW', 'Month', 'Two+ Prop']
# ['County', 'Year', 'DOW', 'Month', 'Two+ Prop']
# ['County', 'Year', 'DOW', 'Month', 'HighIncome Prop']
# ['County', 'Year', 'DOW', 'Month', 'HighIncome Prop']
# ['County', 'Year', 'DOW', 'Month', 'MidIncome Prop']
# ['County', 'Year', 'DOW', 'Month', 'MidIncome Prop']
# ['County', 'Year', 'DOW', 'Month', 'Middle-Old Prop']
# ['County', 'Year', 'DOW', 'Month', 'Middle-Old Prop']
# ['County', 'Year', 'DOW', 'Month', 'Middle-Young Prop']
# ['County', 'Year', 'DOW', 'Month', 'Middle-Young Prop']
# ['County', 'Year', 'DOW', 'Month', 'Old Prop']
# ['County', 'Year', 'DOW', 'Month', 'Old Prop']
# Best Subset of size  5 :  ['County', 'Year', 'Poverty ', 'DOW', 'Month']  has r2: 0.3221191921740598
# Best Subset of size  5 :  ['County', 'Year', 'Poverty ', 'DOW', 'Month']  has rmse: 0.045859387259202175
# ['County', 'Year', 'Poverty ', 'Population', 'DOW', 'Month']
# ['County', 'Year', 'Poverty ', 'Population', 'DOW', 'Month']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'White Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'White Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Black Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Black Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Native American Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Native American Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Asian Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Asian Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Pacific Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Pacific Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Two+ Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Two+ Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'HighIncome Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'HighIncome Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'MidIncome Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'MidIncome Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Middle-Old Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Middle-Old Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Middle-Young Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Middle-Young Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Old Prop']
# ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Old Prop']
# Best Subset of size  6 :  ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'HighIncome Prop']  has r2: 0.3224957858693167
# Best Subset of size  6 :  ['County', 'Year', 'Poverty ', 'DOW', 'Month', 'Pacific Prop']  has rmse: 0.045855584186534314

# %%
betas = {}
rsquares = {}
for z in range (1,15):
    X_train, X_test, y_train, y_test = train_test_split(df, response_df, test_size=0.1, random_state=420*z)
    x_mat = make_dummies(X_train[best_rmse_subset], best_rmse_subset)
    x_columns = x_mat.columns
    x_mat = x_mat.to_numpy()
    response_mat = y_train['Bottles Sold PC'].to_numpy()
    rsquares[z] = run_cross_val(np.asmatrix(x_mat), 5, "OLS")['avg r_2']
    betas[z] = np.matmul(np.matmul(np.linalg.inv(np.matmul(x_mat.transpose(), x_mat)), x_mat.transpose()), response_mat)
    
beta_df = pd.DataFrame(betas)
beta_df.insert(0, "predictor", x_columns)

# %%
beta_df.to_csv("bottles_sold_r2_betas.csv")

# %%
rsquares
# Out:
# {1: 1.428423212503549,
#  2: 1.4219579425943314,
#  3: 1.4235982016250683,
#  4: 1.4221285336749876,
#  5: 1.4308388035839332,
#  6: 1.425912521364928,
#  7: 1.4282156689442203,
#  8: 1.418300387966935,
#  9: 1.4297418805960915,
#  10: 1.4273030370101802,
#  11: 1.4287506639990597,
#  12: 1.4266782511790914,
#  13: 1.4300898454839774,
#  14: 1.4276671841919426}

# %%
y_train
# Out:
#        Volume Sold PC  Bottles Sold PC  Sales Volume PC
# 34898        0.014634         0.020819         0.226114
# 5428         0.013414         0.014961         0.158884
# 9519         0.061306         0.066345         0.957375
# 22510        0.081620         0.078482         1.125014
# 6947         0.160051         0.141934         2.110881
# ...               ...              ...              ...
# 64094        0.006415         0.013752         0.162115
# 475          0.025795         0.028690         0.416243
# 6549         0.031796         0.028419         0.370869
# 63407        0.084817         0.092700         1.045115
# 64266        0.141021         0.144955         2.076629
#
# [62498 rows x 3 columns]
